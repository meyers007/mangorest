# %%
# %reload_ext autoreload
# %autoreload 2
import colabexts
from colabexts.jcommon import *

jpath=os.path.dirname(colabexts.__file__)
jcom = f'{jpath}/jcommon.ipynb'
# %run $jcom

import os, sys, datetime, re, json, importlib
from collections import defaultdict
from sys import modules
from IPython.display import HTML, Javascript
import warnings
import pandas as pd
warnings.filterwarnings('ignore')

# %matplotlib inline
pd.set_option('display.max_colwidth', 8)
pd.set_option('display.max_rows', 8)
# Out:
# <textarea rows=5 id=nav_head_content style="width:100%;display:none;">
# <style>
# a.bh,  a.bh:visited, a.bh:link, a.bh:active {
#   ttext-decoration: none;
#   color: black;
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   font-size: 3em
# }
# </style>
# <div id='HTMLTopBar' style="
#     z-index: 50;
#     align-items: stretch;
#     width:100%">
#     <div  style="
#         text-color: black;
#         background-color: #fefefe;
#         bborder-bottom: 1px dotted gray;
#         padding-left: 2px;
#         box-shadow: 5px 1px #ccc;
#         height: 40px; left: 0;
#         padding: 14px;
#         "
#     >
#     <a class=bh1 href="#" onclick="$('#maintoolbar').toggle();">X</a>
# </div>
# </textarea>
#
# <script>
# if ($('#nav_head').length < 1) {
#     $('#notebook-container').prepend('<div id="nav_head" style="width:100%;">.</div>')
#     console.log("Added a div")
# } else{
#     console.log("Already Added")
# }
#
# $('#nav_head').html($('#nav_head_content').val())
#
# $('.nbp-app-bar').toggle()
# </script>
# <style>
# @import url('https://fonts.googleapis.com/css2?family=Roboto&display=swap');
# </style>
# <style>
# <link href="https://fonts.googleapis.com/css2?family=Roboto&display=swap"
#                             rel="stylesheet">
#
# body  p ol li {
#     font-family: "Roboto",  "Lucida Grande", "Lucida Sans Unicode";
#     font-size: 14px;
#     background: #fff
# }
#
# h1, h2, h3{
#     font-family: 'Roboto', sans-serif;
# }
# div#notebook_panel div#notebook{
#     background: #ffffff
# }
# div#notebook-container{
#     box-shadow: 0px;
#     padding: 0px;
#     border-left: .05em dotted gray;
#     -webkit-box-shadow: 0px;
#     box-shadow: none;
# }
# </style>
# <style>
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
# .CodeMirror {
#     font-family: monospace;
# }
# div.input_area {
#     border: 0px;
# }
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# div#notebook{
#     padding-top: 0px;
# }
# div.prompt_container {
#     display: block;
#     background: #f7f7f7;
# }
# div.prompt{
#     min-width:0px;
#     display: grid;
# }
# div.cell{
#     padding-bottom: 5px;
#     padding-left: 0px;
# }
#
# a.bh,  a.bh:visited, a.bh:link, a.bh:active {
#   text-decoration: none;
#   color:white;
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   font-size:1em
# }
# a.bh:hover {
#   color: #ffccdd;
# }
#
# a.bh1,  a.bh1:visited, a.bh1:link, a.bh1:active {
#   text-decoration: none;
#   color: rgba(0, 0, 0, 0.87);
#   font-family: 'Roboto','Heebo',Arial,sans-serif;
#   padding-right: 30px;
#   font-size:1.1em
# }
# a.bh1:hover {
#   color: rgba(0, 0, 0, 0.57);
# }
#
# #toc-wrapper {
#    font-family: 'Roboto','Heebo',Arial,sans-serif;
#     border: 0px dotted gray;
#     padding: 10px;
#     line-height: 1.8em;
# }
# </style>
# <script>
# l="https://www.ancient-symbols.com/images/wp-image-library/fullsize/infinity.jpg"
# l="imgs/logo.png"
# l=""
# $('#ipython_notebook').html(`<img src="${l}">`)
#
# </script>

# %%
# %%writefile  mangorest/mango.py
#!/usr/local/bin/python
import sys, os,datetime, pkgutil, inspect,hashlib, json, django
from django.conf.urls import url
from django.urls import path
from django.shortcuts import render
from django.http import HttpResponse, JsonResponse
from django.contrib.auth.decorators import login_required
from django.core.files.storage import default_storage
from django.core.files.base import ContentFile
from django.core.serializers.json import DjangoJSONEncoder
from django.conf import settings
from django.core.wsgi import get_wsgi_application
from django.core.management import execute_from_command_line
import numpy as np

'''
References: 
https://blog.miguelgrinberg.com/post/the-ultimate-guide-to-python-decorators-part-iii-decorators-with-arguments
https://simpleisbetterthancomplex.com/article/2017/08/07/a-minimal-django-application.html

'''
__VERSION__ = "1.0"
PORT        = 9000
#--------------------------------------------------------------------------------
def index(request):
    return HttpResponse(f"Version: {__VERSION__}");
#--------------------------------------------------------------------------------
DEBUG=0
def logp(*args, **kwargs):
    if not DEBUG:
        return;
    
    for c in kwargs:
        print(kwargs[c], end=" ")
    for c in args:
        print(c, end=" ")
    print()
#--------------------------------------------------------------------------------
def Debug(request, APPNAME=''):
    rpath = request.path.split('/')[-2] #en(APPNAME)+2:-1]
    template = "/templates/" + rpath;
    pyModule = rpath;
    
    logp(f"{template} Requested")
    getlist = [ c for c in request.GET.items()]
    ret = f''' <pre>\n Response Object: \n{os.getcwd()} path_info:{request.path_info}: final:{rpath}
               Page exists:  {template} : {os.path.exists(template)}
               Page exists:  {pyModule} : {os.path.exists(pyModule)}
               {getlist} </pre> '''
    return HttpResponse(ret);
#--------------------------------------------------------------------------------
# ALL you need to do is just define a function as follows
# def test(a=n, **kwargs):
#    #do your stuff
#    return 
# This function will take care of the rest

class myEncoder(DjangoJSONEncoder):
    def default(self, obj):
        logp("============>. {obj} {typeof(obj)}")
        if isinstance(obj, np.int64):
            return int(obj)
        else:
            return super(DjangoJSONEncoder, self).default(obj)
#--------------------------------------------------------------------------------
def CallMethod(method, request, args=None):
    if(args is None):
        args = inspect.getfullargspec(method)
    
    if (args.varkw == None ):
        #logp(f"ViewCommon: No kwargs?:Calling ...{method}(request)");
        return method(request)
    
    #logp(f"ViewCommon: KWARGS:Calling ...");
    par = dict(request.GET)
    par.update(request.POST)
    
    #paramters comes in as arrays 
    for k in par.keys():
        if len(par[k]) <= 1:
            par[k] = par[k][-1]  
    
    par["request"] = request

    ret = method(**par)
    if ('content_type' in par and par['content_type'] == 'json'):
        if (type(ret) == str):
            ret = json.loads(ret)
            
        return JsonResponse(ret, safe=False)
    
    #logp(f'returning {ret} {type(ret)}')
    
    if (isinstance(ret, django.http.response.HttpResponseBase) ):
        return ret;
    
    if (type(ret) != str):
        ret = json.dumps(ret, cls=myEncoder)
        
    return HttpResponse(ret) #, content_type="text/plain")
#--------------------------------------------------------------------------------
def TryRunPyMethod(request):
    rpaths = [c for c in request.path.split("/") if (c) ];
    pyMethod = rpaths[-1];
 
    #logp(f"importing ... {pyMethod} ...")
    if ( pyMethod.find("modules.") < 0 ):
        return HttpResponse(f"{pyMethod} not understood 0")
        
    spl = pyMethod.split('.');
 
    if ( len(spl) < 2):
        logp("Hmmm ... May be not what is intended!! module name")
        return HttpResponse(f"{pyMethod} not understood 2");
    
    modName = ".".join(spl[:-1])
    __import__(modName, fromlist="dummy")
    
    funName = spl[-1]
    for v in sys.modules:
        if (v.startswith(modName)):
            method= getattr(sys.modules[v], funName)
            logp("==>", v, type(v), funName, method, type(method), callable(method))
            return CallMethod(method, request)
        
    return HttpResponse(f"{pyMethod} not understood3 ");
    
#--------------------------------------------------------------------------------
'''
USE following methods to pass in AUTH Key:
    curl -i -H "APK: 123"  http://localhost:9000
'''
def AuthorizeAPIKEY(request):
    apk = request.headers.get("APK", "")
    apk = apk or request.GET.get("APK", "?")
    apk = apk or request.POST.get("APK", "")
    # print(f"====> FOUND {request.path} {apk} ++")
    # Validate APK Key and return "Eror Description"

def AuthorizeNone(request):
        return ""
    
AUTH_METHOD = AuthorizeNone
#--------------------------------------------------------------------------------
@login_required(login_url='/accounts/login/')
def CommonSecured(request, apage):
    return render(request, apage)
#--------------------------------------------------------------------------------
def Common(request):
    path = request.path[:-1] if request.path.endswith("/") else request.path
    if ( path.endswith("favicon.ico")):
        return HttpResponse(f"{path}!!");
    
    # Check for authorizaton and version request
    authError = AUTH_METHOD(request)
    if ( authError ):
        return HttpResponse(f"{path} -- {authError}!!");

    # Next STEP 1: check with registered URLS
    logp(f'*Check: {path} registered URLS: {_WEBAPI_ROUTES.keys()}')
    
    if (path in _WEBAPI_ROUTES.keys() ):
        f, args, auth, opts = _WEBAPI_ROUTES[path]
        if ( auth ):
            ret = auth(request)
            if ( ret ):
                return HttpResponse(f"{path} -- {authError}!!"); 
        return CallMethod(f,request, args)


    # If not in the registered do templates:
    
    rpaths = [c for c in path.split("/") if (c)];
    if (len(rpaths) < 1):
        return index(request)
    
    template = f"{rpaths[0]}/templates/{'/'.join(rpaths[1:])}";
    rpath    = "/".join(rpaths[1:]);
    
    logp(rpaths, f'=*=>{path} {template}; {rpaths} ++ {rpath}');
    
    if ( os.path.exists(template) and request.path.find("/secured/") > 0) : 
        logp("Secured ==> " , rpaths, "==>", template);
        return CommonSecured(request, rpath)
    elif ( os.path.exists(template) ):
        return render(request, rpath)
    elif rpaths[-1].find("services.") >= 0: #Must be a python module call
        logp("**** Getting python Module")
        return TryRunPyMethod(request)
    
    return HttpResponse(f"{path} not understood");
    
#--------------------------------------------------------------------------------
_WEBAPI_ROUTES={}
def webapi(url, auth=None, **kwargs):
    if auth and not inspect.isfunction(auth):
        auth = AuthorizeAPIKEY
        
    if type(url) is not str:
        f = url
        url = f'/{f.__module__}.{f.__name__}'
        m = inspect.getfullargspec(f)
        print(f"Registering url: {url} {f} {type(url)}")
        _WEBAPI_ROUTES[url] = [f, m, auth, kwargs]
        
        return f
    
    def inner_decorator(f):
        if url in _WEBAPI_ROUTES:
            print(f"Warning: Duplicate registration: {url} ")

        m = inspect.getfullargspec(f)
        url1 = url if url.startswith("/") else "/"+url
        url1 = url1[:-1] if url1.endswith("/") else url1
        
        _WEBAPI_ROUTES[url1] = [f, m, auth, kwargs]

        return f

    return inner_decorator
#----------------------------------------------------------------------------------
def inJupyter():
    try:    get_ipython; return True
    except: return False
#--------------------------------------------------------------------------------
SECRET        = f'{os.name}{os.getcwd()}{datetime.datetime.now()}'
DEBUG         = True
SECRET_KEY    = hashlib.sha224(bytes(SECRET, 'utf-8')).hexdigest()
ALLOWED_HOSTS = ['*']
#--------------------------------------------------------------------------------
def main():
    os.environ.setdefault('DJANGO_SETTINGS_MODULE', __file__)
    settings.configure(
            DEBUG                 = DEBUG,
            SECRET_KEY            =  SECRET_KEY,
            ROOT_URLCONF          = __name__,
            BASE_DIR              =  os.getcwd(),
            ALLOWED_HOSTS         = ALLOWED_HOSTS,
            CORS_ORIGIN_ALLOW_ALL = True,   
            CSRF_COOKIE_HTTPONLY  = False,
            CSRF_COOKIE_SECURE    = False,
            AUTHORIZE             = "", #Can be a Function, method,
            MIDDLEWARE_CLASSES=(
                'django.middleware.common.CommonMiddleware',
            ),
        )
    
    argv = [c for c in sys.argv]
    if len(argv) <= 1:
        print(f"** NOTICE ***\n\nTry running: {sys.argv[0]} runserver 0:9000 #to run on port 9000\n***\n")
        argv.extend(["runserver", f"0:{PORT}"])
    execute_from_command_line(argv)

urlpatterns = (
    url(r'^.*', Common, name='catchall'),
)
    
if __name__ == '__main__' and not inJupyter():
    main()
    pass
# Out:
# [autoreload of django.conf failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 330, in update_generic
#     if type_check(a, b):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 316, in <lambda>
#     (lambda a, b: isinstance2(a, b, type),
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 312, in isinstance2
#     return isinstance(a, typ) and isinstance(b, typ)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 224, in inner
#     return decorator
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 68, in _setup
#     % (desc, ENVIRONMENT_VARIABLE))
# django.core.exceptions.ImproperlyConfigured: Requested settings, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.utils.translation failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 11, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.http.request failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/http/request.py", line 23, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.core.signing failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/core/signing.py", line 47, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.utils.http failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/http.py", line 19, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.http.response failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/http/response.py", line 20, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.db.models failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/db/models/__init__.py", line 7, in <module>
#     from django.db.models.deletion import (
# ImportError: cannot import name 'RESTRICT' from 'django.db.models.deletion' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/db/models/deletion.py)
# ]
# [autoreload of django.db.models.fields failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 148, in __eq__
#     def __cast(self):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 136, in __cast
#     return getattr(res, method_name)(*args, **kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 124, in __text_cast
#     if cls._delegate_text:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.utils.html failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/html.py", line 14, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.utils.text failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/text.py", line 10, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.forms.widgets failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/forms/widgets.py", line 19, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.template.base failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/template/base.py", line 61, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.utils.dateformat failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/dateformat.py", line 21, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.utils.datetime_safe failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/datetime_safe.py", line 15, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.forms.fields failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/forms/fields.py", line 32, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.core.validators failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/core/validators.py", line 10, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.utils.dateparse failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/dateparse.py", line 10, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.forms.models failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 148, in __eq__
#     def __cast(self):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 136, in __cast
#     return getattr(res, method_name)(*args, **kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 124, in __text_cast
#     if cls._delegate_text:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.core.checks failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/core/checks/__init__.py", line 8, in <module>
#     import django.core.checks.async_checks  # NOQA isort:skip
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/core/checks/async_checks.py", line 12, in <module>
#     @register(Tags.async_support, deploy=True)
# AttributeError: type object 'Tags' has no attribute 'async_support'
# ]
# [autoreload of django.core.cache failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/core/cache/__init__.py", line 19, in <module>
#     from django.core.cache.backends.base import (
# ImportError: cannot import name 'InvalidCacheKey' from 'django.core.cache.backends.base' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/core/cache/backends/base.py)
# ]
# [autoreload of django.utils.translation.trans_real failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/trans_real.py", line 17, in <module>
#     from django.utils.regex_helper import _lazy_re_compile
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.db.models.functions failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/db/models/functions/__init__.py", line 2, in <module>
#     from .datetime import (
# ImportError: cannot import name 'ExtractIsoWeekDay' from 'django.db.models.functions.datetime' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/db/models/functions/datetime.py)
# ]
# [autoreload of django.db.models.constraints failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 289, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 265, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __eq__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of django.db.models.fields.files failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 148, in __eq__
#     def __cast(self):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 136, in __cast
#     return getattr(res, method_name)(*args, **kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 124, in __text_cast
#     if cls._delegate_text:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.db.models.fields.related failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 148, in __eq__
#     def __cast(self):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 136, in __cast
#     return getattr(res, method_name)(*args, **kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 124, in __text_cast
#     if cls._delegate_text:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.urls.resolvers failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/urls/resolvers.py", line 24, in <module>
#     from django.utils.regex_helper import _lazy_re_compile, normalize
# ImportError: cannot import name '_lazy_re_compile' from 'django.utils.regex_helper' (/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/regex_helper.py)
# ]
# [autoreload of django.db.models.fields failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 147, in __eq__
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 152, in __cast
#     return self.__text_cast()
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 140, in __text_cast
#     return func(*self.__args, **self.__kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.forms.widgets failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 147, in __eq__
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 152, in __cast
#     return self.__text_cast()
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 140, in __text_cast
#     return func(*self.__args, **self.__kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.forms.fields failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 147, in __eq__
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 152, in __cast
#     return self.__text_cast()
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 140, in __text_cast
#     return func(*self.__args, **self.__kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.core.validators failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 147, in __eq__
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 152, in __cast
#     return self.__text_cast()
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 140, in __text_cast
#     return func(*self.__args, **self.__kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# Overwriting mangorest/mango.py
# [autoreload of django.forms.models failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 147, in __eq__
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 152, in __cast
#     return self.__text_cast()
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 140, in __text_cast
#     return func(*self.__args, **self.__kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.db.models.fields.files failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 147, in __eq__
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 152, in __cast
#     return self.__text_cast()
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 140, in __text_cast
#     return func(*self.__args, **self.__kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]
# [autoreload of django.db.models.fields.related failed: Traceback (most recent call last):
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 331, in update_generic
#     update(a, b)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 279, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 147, in __eq__
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 152, in __cast
#     return self.__text_cast()
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/functional.py", line 140, in __text_cast
#     return func(*self.__args, **self.__kw)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 92, in gettext
#     return _trans.gettext(message)
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/utils/translation/__init__.py", line 57, in __getattr__
#     if settings.USE_I18N:
#   File "/Users/snarayan/anaconda3.7/anaconda3/lib/python3.7/site-packages/django/conf/__init__.py", line 83, in __getattr__
#     self._setup(name)
# django.core.exceptions.ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
# ]

# %%
# %%writefile  mangorest/dirlist.py
#!/usr/local/bin/python
'''
Directory Listing Service
'''
import os, sys, datetime, re, json, importlib, glob
from django.http import HttpResponse, JsonResponse,FileResponse
import mangorest.mango
from   mangorest.mango import webapi
import mimetypes

base = "/opt/data/ANALYSIS/data"

@webapi("/data")
def dirlist(**kwargs):
    
    if (kwargs.get("file" , None)):
        f = kwargs.get("file")
        if ( not os.path.isfile(f) ):  
            return f"{f} is not a file"
        
        response = FileResponse(open(f, 'rb'))
        ct = list(response._headers['content-type'])
        #print(f" ==> {vars(response)} {ct}") 
        if ( ct[1] == "text/csv"):
            ct[1] = "text/html"
            
        #print(f" ==> {response.headers['Content-Type']} ") 
        return response
        
    dirs= kwargs.get("base" , f"{base}/*")
    req = kwargs.get("request", None)
    url = (req and req.build_absolute_uri()) or "http://localhost:80/data/"
    url = url.split('?')[0].strip('/')
    
    print(f"===>  {dirs} {url}")
    if ( os.path.isdir(dirs)):
        dirs = dirs + "/**"
        
    fil = glob.glob(f'{dirs}', recursive=True)
    
    ret = "".join([f'<li><a href={url}?file={f}>{url}?file={f}</a>' for f in fil])
    return f"<h1>Directory listing for: {base} </h1><br/>" + ret
# Out:
# Writing mangorest/dirlist.py

# %% [markdown]
# # Create Some Examples

# %%
# %%writefile  test/simple.py
#!/usr/local/bin/python
import mangorest.mango
import myfile
    
mangorest.mango.__VERSION__ = "1.1"
mangorest.mango.PORT        = 9000
if __name__ == '__main__' and not mangorest.mango.inJupyter():
    print(f'** NOTICE *** registered URLS: {mangorest.mango._WEBAPI_ROUTES.keys()}')
    mangorest.mango.main()
    pass
# Out:
# Writing test/simple.py

# %%
#%%writefile  test/myfile.py
from  mangorest.mango import webapi

@webapi
def ws1(h='param1', **kwargs):
    ret = (f"Web Service {h} {kwargs}")
    return ret

@webapi("/ws2")
def ws2(**kwargs):
    ret = (f"Web service 2 {kwargs}")
    return ret
# Out:
# Registering url: /__main__.ws1 <function ws1 at 0x7f9e58178ea0> <class 'str'>

# %% [markdown]
# # ALL in one file

# %%
# %%writefile  test/test.py
#!/usr/local/bin/python
import mangorest.mango
from   mangorest.mango import webapi

@webapi
def test1(h='test1', **kwargs):
    ret = (f"Hello Test1 {h} {kwargs}")
    print(ret)
    return ret

@webapi("/app1/testingroot2/")
def test2(request, h="test2", **kwargs):
    ret = (f"Hello Test2 {h} {kwargs} {request.headers}")
    ret = (f"Hello Test2 {h} {kwargs}")

    print(ret)
    return ret

mangorest.mango.__VERSION__ = "1.1"
mangorest.mango.PORT        = 9001
if __name__ == '__main__' and not mangorest.mango.inJupyter():
    print(f'** NOTICE *** registered URLS: {mangorest.mango._WEBAPI_ROUTES.keys()}')
    mangorest.mango.main()
    pass
# Out:
# Overwriting test/test.py
